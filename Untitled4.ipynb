# %%
 def convertTuple(tup): 
    str =  ''.join(tup) 
    return str
tuple = ('t', 'e', 'n', 't', 's') 
str = convertTuple(tuple) 
print(str)
# Out:
# tents

# %%
 
x = (5, 10, 15, 20)
y = reversed(x)
print(tuple(y))

# %%
 
 
def sum_list(items):  
  sum = 0   
  for x in items:     
   sum += x   
  return sum
print(sum_list([1,2,-8]))
# Out:
# -5

# %%
my_dict = {'data1':100,'data2':-54,'data3':247}
print(sum(my_dict.values()))
# Out:
# 293

# %%
 
x = ("w3resource")
y = reversed(x)
print(tuple(y))
x = (5, 10, 15, 20)y = reversed(x)print(tuple(y))
# Out:
#   File "<ipython-input-13-b265fb239d65>", line 2
#     x = ("w3resource")y = reversed(x)print(tuple(y))x = (5, 10, 15, 20)y = reversed(x)print(tuple(y))
#                       ^
# SyntaxError: invalid syntax
